# %% [markdown]
# # 3. Import the 'orders_products_combined' dataframe from the pickle file you just saved.

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# create path variable
path = r'C:\Users\justi\Downloads\05-2024 Instacart Basket Analysis_JB\05-2024 Instacart Basket Analysis'

# use path and retrieve prepared "Products" data
df_prods = pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# Use path again and import the new pkl file and call it 'df_ords_prods_combined'
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 4. Check the shape of the imported dataframe

# %%
# checking shape still contains 320,541 rows
df_ords_prods_combined.shape
# Out:
# (320541, 11)

# %% [markdown]
# # 5. Determine a suitable way to combine the 'orders_products_combined' dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
df_ords_prods_combined
# Out:
#         Unnamed: 0  order_id  user_id  order_number  order_dow  \
# 0               42     94891        4             4          5
# 1               42     94891        4             4          5
# 2               70     23391        7            17          0
# 3               70     23391        7            17          0
# 4               70     23391        7            17          0
# ...            ...       ...      ...           ...        ...
# 320536     1048554     96551    63098            14          0
# 320537     1048554     96551    63098            14          0
# 320538     1048554     96551    63098            14          0
# 320539     1048554     96551    63098            14          0
# 320540     1048554     96551    63098            14          0
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                      13                      15       22199
# 1                      13                      15       25146
# ...

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# 'df_ords_prods_combined' dataframe has 'Unnamed: 0' and '_merge' columns. 'df_prods' had 'Unnamed: 0'. I remove it by using .drop([]) function.
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0', '_merge'])
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_ords_prods_combined
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          94891        4             4          5                 13
# 1          94891        4             4          5                 13
# 2          23391        7            17          0                 10
# 3          23391        7            17          0                 10
# 4          23391        7            17          0                 10
# ...          ...      ...           ...        ...                ...
# 320536     96551    63098            14          0                  8
# 320537     96551    63098            14          0                  8
# 320538     96551    63098            14          0                  8
# 320539     96551    63098            14          0                  8
# 320540     96551    63098            14          0                  8
#
#         days_since_prior_order  product_id  add_to_cart_order  reordered
# ...

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# Now merge both 'df_ords_merged' and 'df_prods' to create a new dataframe called 'df_op_merged'
df_op_merged = df_prods.merge(df_ords_prods_combined, on = 'product_id', indicator = True)
df_op_merged
# Out:
#         product_id                product_name  aisle_id  department_id  \
# 0                1  Chocolate Sandwich Cookies        61             19
# 1                1  Chocolate Sandwich Cookies        61             19
# 2                1  Chocolate Sandwich Cookies        61             19
# 3                1  Chocolate Sandwich Cookies        61             19
# 4                1  Chocolate Sandwich Cookies        61             19
# ...            ...                         ...       ...            ...
# 320245       49683              Cucumber Kirby        83              4
# 320246       49683              Cucumber Kirby        83              4
# 320247       49683              Cucumber Kirby        83              4
# 320248       49683              Cucumber Kirby        83              4
# 320249       49688      Fresh Foaming Cleanser        73             11
#
#         prices  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# ...

# %% [markdown]
# # 6. Confirm the results of the merge using the merge flag.

# %%
# Validate all rows have been merged using .valid_counts() function
df_op_merged['_merge'].value_counts()
# Out:
# _merge
# both          320250
# left_only          0
# right_only         0
# Name: count, dtype: int64

# %% [markdown]
# # 7. Export the newly created dataframe as ords_prods_merge in a suitable format (taking into consideration the size).

# %%
# Export 'df_op_merged' into pkl file and label as 'ords_prods_merge.pkl'
df_op_merged.to_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'ords_products_merged.pkl'))
